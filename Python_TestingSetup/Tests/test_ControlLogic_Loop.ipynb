# %%
# import required libs
import numpy as np
import sys
sys.path.append(r"../Communiaction")
sys.path.append(r"../Utils")
import TCP_IP_UTILS
import Utils
import time

# %%
#connect to ethernet socket 
HOST = '192.168.1.10'  # Remote device IP (server IP)
PORT = 7               # Echo port
client_socket = TCP_IP_UTILS.tcp_connect(HOST,PORT)
#Set IOs to default before turning on powersupply
ret_data = Utils.Set_ChipIO_to_Default(client_socket)
print(ret_data)
time.sleep(1) #Wait for IOs to settle
# Out:
# [Client] Connected to 192.168.1.10:7
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Default Signals Set
# [128]

# %%
#Add power supply code here

# %%
#Create Checker pattern for test. Make sure calib supplys are off.
rows, cols = 296, 1156
checkerboard = np.fromfunction(lambda i, j: (i + j + 1 ) % 2, (rows, cols), dtype=int)
# Step 2: Create zero array of full shape
full_array = np.zeros(shape=(320, 1156),dtype=np.uint8) #320 is the padded list.
# Step 3: Insert checkerboard into left part (first 296 columns)
full_array[:rows, :] = checkerboard
#full_array[:rows, :] = 1
#full_array[4:8,:] = 1
#full_array[0:8,:] = 0
#full_array[6:8,:] = 1
#num_ones = 1156*200
# Random positions
#ones_positions = np.random.choice(rows * cols, num_ones, replace=False)
#full_array.flat[ones_positions] = 1
full_array = full_array.flatten(order='F') #Across Column

# %%
#Call Write SRAM here
write_data = full_array.tolist()  #Remember this is in bits. Will be converted to bytes inside
ret_data = Utils.Write_SRAM(client_socket,write_data,1)
print(ret_data)
# Out:
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 6
# Received Data Size: 1
# All Data Received
# [128]

# %%
#Charge domain sequence

IN_LB = 6'd0;
IN_UB = 6'd0; 
TDC_EN_LB = 6'd5;
TDC_EN_UB = 6'd13;
CHG_EN_LB = 6'd2;
CHG_EN_UB = 6'd3;
TIME_EN_LB = 6'd0;
TIME_EN_UB = 6'd0;
PCHG_LB = 6'd1;
PCHG_UB = 6'd4;
VDAC_CTRL_LB = 6'd2;
VDAC_CTRL_UB = 6'd15; 
DEL_RST_LB = 6'd0;
DEL_RST_UB = 6'd0;
TDC_COMPUTE_LB = 6'd11;
TDC_COMPUTE_UB = 6'd16;
TDC_RST_LB = 6'd1;
TDC_RST_UB = 6'd13;
BL_NUM_TGT = 2'd3;
BL_DONE_TIME = 6'd20;
VTC_EN_LB = 6'd5;
VTC_EN_UB = 6'd14;
SAMPLE_EDGE_TIME = 6'd8;

#Time Domain
IN_LB = 6'd3;
IN_UB = 6'd22; 
TDC_EN_LB = 6'd1;
TDC_EN_UB = 6'd21;
CHG_EN_LB = 6'd0;
CHG_EN_UB = 6'd0;
TIME_EN_LB = 6'd0;
TIME_EN_UB = 6'd0;
PCHG_LB = 6'd2;
PCHG_UB = 6'd22;
VDAC_CTRL_LB = 6'd0;
VDAC_CTRL_UB = 6'd0; 
DEL_RST_LB = 6'd2;
DEL_RST_UB = 6'd22;
TDC_COMPUTE_LB = 6'd19;
TDC_COMPUTE_UB = 6'd22;
TDC_RST_LB = 6'd1;
TDC_RST_UB = 6'd21;
BL_NUM_TGT = 2'd3;
BL_DONE_TIME = 6'd25;
VTC_EN_LB = 6'd0;
VTC_EN_UB = 6'd0;
SAMPLE_EDGE_TIME = 6'd8;

# %%
import numpy as np
import random
import re
def scan_gen(time):
    SC_data = f"""
    IN_EXT_LOC = 1'b0;
    TDC_EN_EXT_LOC = 1'b0;
    ENCHG_EXT_LOC = 1'b0;
    ENTIME_EXT_LOC = 1'b1;
    PCHG_EXT_LOC = 1'b0;
    VDAC_CTRL_EXT_LOC = 1'b0;
    DEL_RST_EXT_LOC = 1'b0;
    TDC_COMPUTE_EXT_LOC = 1'b0;
    TDC_RST_EXT_LOC = 1'b0;
    VTC_EN_EXT_LOC = 1'b0;

    IN_LB = 6'd3;
    IN_UB = 6'd22; 
    TDC_EN_LB = 6'd1;
    TDC_EN_UB = 6'd21;
    ENCHG_LB = 6'd0;
    ENCHG_UB = 6'd0;
    ENTIME_LB = 6'd0;
    ENTIME_UB = 6'd0;
    PCHG_LB = 6'd2;
    PCHG_UB = 6'd22;
    VDAC_CTRL_LB = 6'd0;
    VDAC_CTRL_UB = 6'd0; 
    DEL_RST_LB = 6'd2;
    DEL_RST_UB = 6'd22;
    TDC_COMPUTE_LB = 6'd19;
    TDC_COMPUTE_UB = 6'd22;
    TDC_RST_LB = 6'd1;
    TDC_RST_UB = 6'd21;
    BL_NUM_TGT = 2'd3;
    BL_DONE_TIME = 6'd25;
    VTC_EN_LB = 6'd0;
    VTC_EN_UB = 6'd0;
    SAMPLE_EDGE_TIME = 6'd{time};

    CHG_TIME = 1'd0;
    OSC_DEL = 1'd0;
    """
    SC_order = ["BL_DONE_TIME","SAMPLE_EDGE_TIME", "BL_NUM_TGT", "BLANK_4", "IN_LB", "TDC_EN_LB", "ENCHG_LB", "IN_EXT_LOC","TDC_EN_EXT_LOC","ENCHG_EXT_LOC",\
                "ENTIME_EXT_LOC","PCHG_EXT_LOC","VDAC_CTRL_EXT_LOC", 'ENTIME_LB', 'PCHG_LB', 'VDAC_CTRL_LB', 'DEL_RST_LB', 'TDC_COMPUTE_LB', 'TDC_RST_LB', \
                'VTC_EN_LB',"DEL_RST_EXT_LOC","TDC_COMPUTE_EXT_LOC","TDC_RST_EXT_LOC","VTC_EN_EXT_LOC","CHG_TIME","OSC_DEL", "VTC_EN_UB","TDC_RST_UB","TDC_COMPUTE_UB",\
                "DEL_RST_UB","VDAC_CTRL_UB","PCHG_UB","ENTIME_UB","ENCHG_UB","TDC_EN_UB","IN_UB","BLANK_12_PISO"]

    lines = SC_data.splitlines()
    sc_signal = {}
    for line in lines:
        if line.strip():  # Skip empty lines
            # Handle 'd' (decimal) format
            match = re.match(r"(\w+) = (\d+)'d([0-9]+);", line.strip())
            if match:
                signal_name = match.group(1)
                num_bits = int(match.group(2))  # Number of bits
                signal_value = match.group(3)  # Decimal value


                # If there's only 1 bit, do not add the bit-range
                if num_bits == 1:
                    name = signal_name
                else:
                    # Format the name with the bit-range (e.g., VTC_EN_UB<[5:0]>)
                    name = "%s" % (signal_name) # Using 0-based index for the range

                # Format the decimal value to binary and pad to the correct number of bits
                binary_value = bin(int(signal_value))[2:].zfill(num_bits)
                sc_signal[name] = binary_value


            # Handle 'b' (binary) format
            elif "b" in line:  # e.g., BL_NUM_TGT = 2'b01;
                match = re.match(r"(\w+) = (\d+)'b([01]+);", line.strip())
                if match:
                    signal_name = match.group(1)
                    num_bits = int(match.group(2))  # Number of bits
                    signal_value = match.group(3)  # Binary value

                    # If there's only 1 bit, do not add the bit-range
                    if num_bits == 1:
                        name = signal_name
                    else:
                        # Format the name with the bit-range (e.g., BL_NUM_TGT<[1:0]> for 2 bits)
                        name = "%s" % (signal_name)

                    # Format the binary value to match the number of bits
                    binary_value = signal_value.zfill(num_bits)
                    sc_signal[name] = binary_value


    # print(sc_signal)
    output_list = []
    for signal in SC_order:
        if "BLANK" in signal:
            num_blanks = re.findall(r'\d+', signal)
            output_list += [0]*int(num_blanks[0])
        else:
            temp = sc_signal[signal][::-1]
            output_list += list(map(int,temp))
    print(sc_signal["SAMPLE_EDGE_TIME"])
    output_list = output_list[::-1] + [0]*30
    return output_list

# %%
out = []
for i in range(0,22):
    #Call Scan IN here with data
    scan_id = Utils.CONTROL_LOGIC_SC["id"]
    scan_len = Utils.CONTROL_LOGIC_SC["len"]
    scan_data = scan_gen(i)
    ret_data = Utils.ScanIN_Data(client_socket,scan_id,scan_len,scan_data,1)
    #print(ret_data)

    signal_array = [Utils.CTRL_EN]
    value_array = [1]
    ret_data = Utils.Set_Chip_IO(client_socket,signal_array,value_array,1)
    #print(ret_data)

    signal_array = [Utils.DFF_RST]
    value_array = [1]
    ret_data = Utils.Set_Chip_IO(client_socket,signal_array,value_array,1)
    #print(ret_data)

    signal_array = [Utils.CTRL_EN]
    value_array = [0]
    ret_data = Utils.Set_Chip_IO(client_socket,signal_array,value_array,1)
    #print(ret_data)

    signal_array = [Utils.SCN_SEL_0,Utils.SCN_SEL_1,Utils.SCN_SEL_2,Utils.CLK_A,Utils.CLK_B,Utils.SCN_IN]
    value_array = [1,1,1,0,0,0]
    ret_data = Utils.Set_Chip_IO(client_socket,signal_array,value_array,1)

    signal_array = [Utils.IN_EN]
    value_array = [1]
    ret_data = Utils.Set_Chip_IO(client_socket,signal_array,value_array,1)
    #print(ret_data)
    signal_array = [Utils.CLK_A]
    value_array = [1]
    ret_data = Utils.Set_Chip_IO(client_socket,signal_array,value_array,1)
    #print(ret_data)
    signal_array = [Utils.CLK_A]
    value_array = [0]
    ret_data = Utils.Set_Chip_IO(client_socket,signal_array,value_array,1)
    #print(ret_data)
    signal_array = [Utils.IN_EN]
    value_array = [0]
    ret_data = Utils.Set_Chip_IO(client_socket,signal_array,value_array,1)
    #print(ret_data)

    #Call Scan OUT here with data
    scan_id = Utils.CONTROL_LOGIC_SC["id"]
    scan_len = Utils.CONTROL_LOGIC_SC["len"]
    scan_out_data = Utils.ScanOUT_Data(client_socket,scan_id,scan_len,1)
    print(len(scan_out_data))
    print(scan_out_data)
    ret_data = Utils.Set_ChipIO_to_Default(client_socket)
    #print(ret_data)
    out.append([scan_out_data[0],scan_out_data[1]])
# Out:
# 000000
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 3
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 4
# Received Data Size: 24
# All Data Received
# 24
# [0, 220, 84, 0, 208, 0, 77, 83, 1, 0, 0, 101, 8, 128, 0, 2, 0, 97, 24, 48, 169, 170, 170, 170]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Default Signals Set
# 000001
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 3
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 4
# Received Data Size: 24
# All Data Received
# 24
# [192, 220, 84, 0, 208, 0, 77, 83, 1, 0, 0, 101, 8, 128, 0, 2, 0, 97, 24, 52, 169, 170, 170, 170]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Default Signals Set
# 000010
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 3
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 4
# Received Data Size: 24
# All Data Received
# 24
# [216, 220, 84, 0, 208, 0, 77, 83, 1, 0, 0, 101, 8, 128, 0, 2, 0, 97, 24, 50, 169, 170, 170, 170]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Default Signals Set
# 000011
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 3
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 4
# Received Data Size: 24
# All Data Received
# 24
# [217, 220, 84, 0, 208, 0, 77, 83, 1, 0, 0, 101, 8, 128, 0, 2, 0, 97, 24, 54, 169, 170, 170, 170]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Default Signals Set
# 000100
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 3
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 4
# Received Data Size: 24
# All Data Received
# 24
# [217, 220, 84, 0, 208, 0, 77, 83, 1, 0, 0, 101, 8, 128, 0, 2, 0, 97, 24, 49, 169, 170, 170, 170]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Default Signals Set
# 000101
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 3
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 4
# Received Data Size: 24
# All Data Received
# 24
# [217, 220, 84, 0, 208, 0, 77, 83, 1, 0, 0, 101, 8, 128, 0, 2, 0, 97, 24, 53, 169, 170, 170, 170]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Default Signals Set
# 000110
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 3
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 4
# Received Data Size: 24
# All Data Received
# 24
# [217, 220, 84, 0, 208, 0, 77, 83, 1, 0, 0, 101, 8, 128, 0, 2, 0, 97, 24, 51, 169, 170, 170, 170]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Default Signals Set
# 000111
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 3
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 4
# Received Data Size: 24
# All Data Received
# 24
# [217, 220, 84, 0, 208, 0, 77, 83, 1, 0, 0, 101, 8, 128, 0, 2, 0, 97, 24, 55, 169, 170, 170, 170]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Default Signals Set
# 001000
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 3
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 4
# Received Data Size: 24
# All Data Received
# 24
# [217, 220, 84, 0, 208, 0, 77, 83, 1, 0, 0, 101, 8, 128, 0, 2, 0, 97, 152, 48, 169, 170, 170, 170]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Default Signals Set
# 001001
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 3
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 4
# Received Data Size: 24
# All Data Received
# 24
# [217, 220, 84, 0, 208, 0, 77, 83, 1, 0, 0, 101, 8, 128, 0, 2, 0, 97, 152, 52, 169, 170, 170, 170]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Default Signals Set
# 001010
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 3
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 4
# Received Data Size: 24
# All Data Received
# 24
# [217, 220, 84, 0, 208, 0, 77, 83, 1, 0, 0, 101, 8, 128, 0, 2, 0, 97, 152, 50, 169, 170, 170, 170]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Default Signals Set
# 001011
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 3
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 4
# Received Data Size: 24
# All Data Received
# 24
# [217, 220, 84, 0, 208, 0, 77, 83, 1, 0, 0, 101, 8, 128, 0, 2, 0, 97, 152, 54, 169, 170, 170, 170]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Default Signals Set
# 001100
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 3
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 4
# Received Data Size: 24
# All Data Received
# 24
# [217, 220, 84, 0, 208, 0, 77, 83, 1, 0, 0, 101, 8, 128, 0, 2, 0, 97, 152, 49, 169, 170, 170, 170]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Default Signals Set
# 001101
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 3
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 4
# Received Data Size: 24
# All Data Received
# 24
# [217, 220, 84, 0, 208, 0, 77, 83, 1, 0, 0, 101, 8, 128, 0, 2, 0, 97, 152, 53, 169, 170, 170, 170]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Default Signals Set
# 001110
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 3
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 4
# Received Data Size: 24
# All Data Received
# 24
# [217, 220, 84, 0, 208, 0, 77, 83, 1, 0, 0, 101, 8, 128, 0, 2, 0, 97, 152, 51, 169, 170, 170, 170]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Default Signals Set
# 001111
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 3
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 4
# Received Data Size: 24
# All Data Received
# 24
# [217, 220, 84, 0, 208, 0, 77, 83, 1, 0, 0, 101, 8, 128, 0, 2, 0, 97, 152, 55, 169, 170, 170, 170]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Default Signals Set
# 010000
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 3
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 4
# Received Data Size: 24
# All Data Received
# 24
# [217, 220, 84, 0, 208, 0, 77, 83, 1, 0, 0, 101, 8, 128, 0, 2, 0, 97, 88, 48, 169, 170, 170, 170]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Default Signals Set
# 010001
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 3
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 4
# Received Data Size: 24
# All Data Received
# 24
# [217, 220, 84, 0, 208, 0, 77, 83, 1, 0, 0, 101, 8, 128, 0, 2, 0, 97, 88, 52, 169, 170, 170, 170]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Default Signals Set
# 010010
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 3
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 4
# Received Data Size: 24
# All Data Received
# 24
# [217, 220, 84, 0, 208, 0, 77, 83, 1, 0, 0, 101, 8, 128, 0, 2, 0, 97, 88, 50, 169, 170, 170, 170]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Default Signals Set
# 010011
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 3
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 4
# Received Data Size: 24
# All Data Received
# 24
# [217, 221, 84, 0, 208, 0, 77, 83, 1, 0, 0, 101, 8, 128, 0, 2, 0, 97, 88, 54, 169, 170, 170, 170]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Default Signals Set
# 010100
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 3
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 4
# Received Data Size: 24
# All Data Received
# 24
# [217, 221, 84, 0, 208, 0, 77, 83, 1, 0, 0, 101, 8, 128, 0, 2, 0, 97, 88, 49, 169, 170, 170, 170]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Default Signals Set
# 010101
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 3
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# [162, 0]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 4
# Received Data Size: 24
# All Data Received
# 24
# [25, 221, 84, 0, 208, 0, 77, 83, 1, 0, 0, 101, 8, 128, 0, 2, 0, 97, 88, 53, 169, 170, 170, 170]
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Default Signals Set

# %%
print(out)
# Out:
# [[0, 220], [192, 220], [216, 220], [217, 220], [217, 220], [217, 220], [217, 220], [217, 220], [217, 220], [217, 220], [217, 220], [217, 220], [217, 220], [217, 220], [217, 220], [217, 220], [217, 220], [217, 220], [217, 220], [217, 221], [217, 221], [25, 221]]

# %%
ret_data = Utils.Set_ChipIO_to_Default(client_socket)
print(ret_data)
# Out:
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Default Signals Set
# [128]

# %%
#Call Read SRAM here
SRAM_DATA = Utils.Read_SRAM(client_socket,1)
print(len(SRAM_DATA))
print(SRAM_DATA)
# Out:
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 5
# Received Data Size: 46240
# All Data Received
# 46240
# [85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 0, 0, 0, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 0, 0, 0, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 0, 0, 0, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 0, 0, 0, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 0, 0, 0, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 0, 0, 0, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 0, 0, 0, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 0, 0, 0, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 0, 0, 0, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 0, 0, 0, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 0, 0, 0, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 0, 0, 0, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 0, 0, 0, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 0, 0, 0, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 0, 0, 0, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 0, 0, 0, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 0, 0, 0, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 0, 0, 0, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 0, 0, 0, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 0, 0, 0, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 0, 0, 0, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 0, 0, 0, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85 ...

# %%
arr = list(full_array)
u8_array = []
for i in range(0, len(arr), 8):
    byte_bits = arr[i:i+8]
    value = sum(bit << j for j, bit in enumerate(byte_bits))  # index 0 is LSB
    u8_array.append(value)

print(u8_array)

if SRAM_DATA == u8_array:
    print("Lists are equal")
else:
    print("Lists are not equal")
# Out:
# [85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 0, 0, 0, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 0, 0, 0, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 0, 0, 0, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 0, 0, 0, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 0, 0, 0, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 0, 0, 0, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 0, 0, 0, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 0, 0, 0, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 0, 0, 0, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 0, 0, 0, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 0, 0, 0, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 0, 0, 0, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 0, 0, 0, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 0, 0, 0, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 0, 0, 0, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 0, 0, 0, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 0, 0, 0, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 0, 0, 0, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 0, 0, 0, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 0, 0, 0, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 0, 0, 0, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 170, 0, 0, 0, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85, 85 ...
# Lists are equal

# %%
ret_data = Utils.Set_ChipIO_to_Default(client_socket)
print(ret_data)
# Out:
# Fn identifier Sent
# Received: 128
# All Data Sent
# Received: 128
# FN: 1
# Received Data Size: 1
# All Data Received
# Default Signals Set
# [128]
