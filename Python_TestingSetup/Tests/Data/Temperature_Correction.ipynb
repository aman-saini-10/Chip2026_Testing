# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset
from scipy.interpolate import interp1d
from matplotlib.ticker import MultipleLocator
# Out:
# C:\Users\91880\AppData\Local\Temp\ipykernel_46208\4099831983.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_excel("temperature.xlsx")
array_uncorrected = np.empty((17,17))
array_corrected = np.empty((17,17))
k = 0
for i in range(-40,130,10):
    array_uncorrected[k] = df[i]
    temp = 'Corr '+ str(i)
    array_corrected[k] = df[temp]
    k = k+1

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rcParams['font.family'] = 'Times New Roman'   # or 'Times New Roman', 'DejaVu Sans', etc.
mpl.rcParams['font.size'] = 12

# Axis-specific defaults
mpl.rcParams['axes.titlesize'] = 12
mpl.rcParams['axes.labelsize'] = 12
mpl.rcParams['xtick.labelsize'] = 12
mpl.rcParams['ytick.labelsize'] = 12
mpl.rcParams['legend.fontsize'] = 10

# %%
x_axis = np.arange(0,257,16)
fig, ax = plt.subplots(figsize=(5, 2))
#plt.title("MAC Temp. Sensitivity (Simulated)")
plt.ylabel("Output Code",fontsize = 12)
plt.xlabel("Input Code",fontsize = 12)
for i in range(0,len(array_corrected),4):
    plt.plot(x_axis,array_uncorrected[i],color = "g",linewidth=1,alpha = 0.7)
    plt.plot(x_axis,array_corrected[i],color = "r",linewidth=1.5)
plt.plot(x_axis,array_uncorrected[i],label = "Before Correction",color = "g",linewidth=1,alpha = 0.7)
plt.plot(x_axis,array_corrected[i], label = " After Correction",color = "r",linewidth=1)
plt.ylim(-30,290)
plt.yticks(range(-30, 290, 60))
plt.xticks(range(0, 260, 32))
plt.grid(True)
ax.grid(True, which='major', linestyle='--', linewidth=1, alpha=0.7)
ax.grid(True, which='minor', linestyle=':', linewidth=1, alpha=0.5)
plt.legend() 
plt.savefig("D:\ISSCC_26\Graphs\Temperature.jpg", dpi=800, bbox_inches="tight")

# %%
x_axis = [0]
fig, ax = plt.subplots(figsize=(3, 2))
#plt.title("MAC wrt Ref(@128) (Simulated)")
plt.ylabel("Output Code",fontsize = 12)
plt.xlabel("Input Code",fontsize = 12)
MAC_TEMP = [115,124,128,136,146]
Legend = ["$-40^\circ$","$0^\circ$","$30^\circ$","$80^\circ$","$120^\circ$"]
for ndx,i in enumerate(MAC_TEMP):
    plt.plot(x_axis,i,marker="o",linewidth=1,alpha = 1,label = Legend[ndx])
    #plt.plot(x_axis,array_corrected[i],color = "r",linewidth=1)
#plt.plot(x_axis,array_uncorrected[i],label = "Before Corrcetion",color = "g",linewidth=1,alpha = 0.7)
#plt.plot(x_axis,array_corrected[i], label = " After Corrcetion",color = "r",linewidth=1)
#plt.ylim(-30,290)
plt.yticks(range(110,150,9))
plt.xticks(range(0, 1, 32))
plt.grid(True)
ax.grid(True, which='major', linestyle='--', linewidth=1, alpha=0.7)
ax.grid(True, which='minor', linestyle=':', linewidth=1, alpha=0.5)
plt.legend() 
plt.savefig("D:\ISSCC_26\Graphs\TemperaturePoint.jpg", dpi=800, bbox_inches="tight")
